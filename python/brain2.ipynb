# %%
from board import Board
import random
import pickle
from Table_ai import Table_ai
import numpy as np

# %%
ai = Table_ai()
b = Board()

# %%
ai.table
# Out:
# {}

# %%
ai.Run(5000,.5, False)
# ai.Run(1, 0, True)
ai.Run(30000, .1)
# ai.Run(30000, .5)
# print("\n\nAfter 0.1 \n\n")
# print("----------------------------")
# print("----------------------------")
# print("----------------------------")


# ai.Run(1, 0, True)
# ai.Run(100000, .2)
# ai.Run(100000, 0.1)
# ai.Run(1000, 0.5)
ai.Run(1000000, 0.05)
print("\n\nFINAL\n\n")
print("----------------------------")
print("----------------------------")
print("----------------------------")

table = ai.Run(3, 0, True)
# Out:
# 5000 0.5 False
# 30000 0.1 False
#
#
# FINAL
#
#
# ----------------------------
# ----------------------------
# ----------------------------
# 3 0 False

# %%
ai.Run(3, 0, True)
# Out:
# 3 0 True
# 0 0.4654 {'wins': 268, 'seen': 584}
# 1 0.5444 {'wins': 299, 'seen': 554}
# 2 0.606 {'wins': 346, 'seen': 575}
# 3 0.6706 {'wins': 18855, 'seen': 28238}
# 4 0.5333 {'wins': 312, 'seen': 583}
# 5 0.5001 {'wins': 284, 'seen': 563}
# 6 0.4249 {'wins': 236, 'seen': 538}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 _ _ _ _ _ _ _
# 1 _ _ _ o _ _ _
#   A B C D E F G
#
# 0 0.1248 {'wins': 58, 'seen': 480}
# 1 0.29 {'wins': 418, 'seen': 1413}
# 2 0.3176 {'wins': 1412, 'seen': 4434}
# 3 0.3579 {'wins': 5698, 'seen': 15889}
# 4 0.3124 {'wins': 1584, 'seen': 4916}
# 5 0.2578 {'wins': 190, 'seen': 714}
# 6 0.1807 {'wins': 99, 'seen': 512}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 _ _ _ x _ _ _
# 1 _ _ _ o _ _ _
#   A B C D E F G
#
# 0 0.6211 {'wins': 447, 'seen': 720}
# 1 0.529 {'wins': 150, 'seen': 283}
# 2 0.5933 {'wins': 781, 'seen': 1295}
# 3 0.6702 {'wins': 7043, 'seen': 10691}
# 4 0.6128 {'wins': 607, 'seen': 986}
# 5 0.6114 {'wins': 561, 'seen': 929}
# 6 0.6285 {'wins': 678, 'seen': 1105}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ o _ _ _
# 2 _ _ _ x _ _ _
# 1 _ _ _ o _ _ _
#   A B C D E F G
#
# 0 0.3399 {'wins': 68, 'seen': 209}
# 1 0.3441 {'wins': 2770, 'seen': 7839}
# 2 0.3286 {'wins': 217, 'seen': 657}
# 3 0.3013 {'wins': 60, 'seen': 203}
# 4 0.3226 {'wins': 192, 'seen': 596}
# 5 0.3208 {'wins': 269, 'seen': 811}
# 6 0.3071 {'wins': 148, 'seen': 496}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ o _ _ _
# 2 _ _ _ x _ _ _
# 1 _ x _ o _ _ _
#   A B C D E F G
#
# 0 0.4274 {'wins': 60, 'seen': 138}
# 1 0.6869 {'wins': 2971, 'seen': 4368}
# 2 0.4316 {'wins': 59, 'seen': 141}
# 3 0.6332 {'wins': 1535, 'seen': 2421}
# 4 0.5765 {'wins': 94, 'seen': 162}
# 5 0.596 {'wins': 360, 'seen': 607}
# 6 0.5127 {'wins': 71, 'seen': 138}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ o _ _ _
# 2 _ o _ x _ _ _
# 1 _ x _ o _ _ _
#   A B C D E F G
#
# 0 0.289 {'wins': 41, 'seen': 139}
# 1 0.2895 {'wins': 44, 'seen': 145}
# 2 0.3206 {'wins': 84, 'seen': 268}
# 3 0.3085 {'wins': 186, 'seen': 579}
# 4 0.3306 {'wins': 267, 'seen': 805}
# 5 0.3019 {'wins': 87, 'seen': 277}
# 6 0.3432 {'wins': 764, 'seen': 2275}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ o _ _ _
# 2 _ o _ x _ _ _
# 1 _ x _ o _ _ x
#   A B C D E F G
#
# 0 0.6051 {'wins': 46, 'seen': 75}
# 1 0.6142 {'wins': 63, 'seen': 103}
# 2 0.6029 {'wins': 369, 'seen': 595}
# 3 0.6974 {'wins': 832, 'seen': 1177}
# 4 0.5809 {'wins': 44, 'seen': 77}
# 5 0.6331 {'wins': 246, 'seen': 384}
# 6 0.6018 {'wins': 31, 'seen': 52}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ o _ _ _
# 3 _ _ _ o _ _ _
# 2 _ o _ x _ _ _
# 1 _ x _ o _ _ x
#   A B C D E F G
#
# 0 0.2937 {'wins': 29, 'seen': 96}
# 1 0.3006 {'wins': 49, 'seen': 157}
# 2 0.3221 {'wins': 77, 'seen': 241}
# 3 0.3585 {'wins': 94, 'seen': 263}
# 4 0.2556 {'wins': 19, 'seen': 75}
# 5 0.3289 {'wins': 115, 'seen': 361}
# 6 0.3241 {'wins': 55, 'seen': 169}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ x _ _ _
# 4 _ _ _ o _ _ _
# 3 _ _ _ o _ _ _
# 2 _ o _ x _ _ _
# 1 _ x _ o _ _ x
#   A B C D E F G
#
# 0 0.681 {'wins': 25, 'seen': 37}
# 1 0.5488 {'wins': 14, 'seen': 25}
# 2 0.5748 {'wins': 13, 'seen': 23}
# 3 0.6275 {'wins': 15, 'seen': 24}
# 4 0.6375 {'wins': 16, 'seen': 25}
# 5 0.6545 {'wins': 147, 'seen': 221}
# 6 0.5477 {'wins': 19, 'seen': 33}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ x _ _ _
# 4 _ _ _ o _ _ _
# 3 _ _ _ o _ _ _
# 2 _ o _ x _ _ _
# 1 o x _ o _ _ x
#   A B C D E F G
#
# 0 0.5561 {'wins': 12, 'seen': 22}
# 1 0.5415 {'wins': 12, 'seen': 22}
# 2 0.5343 {'wins': 13, 'seen': 24}
# 3 0.5524 {'wins': 13, 'seen': 23}
# 4 0.5338 {'wins': 12, 'seen': 22}
# 5 0.4867 {'wins': 17, 'seen': 35}
# 6 0.5538 {'wins': 14, 'seen': 25}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ x _ _ _
# 4 _ _ _ o _ _ _
# 3 _ _ _ o _ _ _
# 2 x o _ x _ _ _
# 1 o x _ o _ _ x
#   A B C D E F G
#
# 0 0.6209 {'wins': 12, 'seen': 20}
# 1 0.5827 {'wins': 12, 'seen': 20}
# 2 0.6147 {'wins': 12, 'seen': 20}
# 3 0.594 {'wins': 12, 'seen': 20}
# 4 0.6084 {'wins': 13, 'seen': 21}
# 5 0.5994 {'wins': 12, 'seen': 20}
# 6 0.615 {'wins': 13, 'seen': 21}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ x _ _ _
# 4 _ _ _ o _ _ _
# 3 o _ _ o _ _ _
# 2 x o _ x _ _ _
# 1 o x _ o _ _ x
#   A B C D E F G
#
# 0 0.6079 {'wins': 12, 'seen': 20}
# 1 0.5978 {'wins': 12, 'seen': 20}
# 2 0.6052 {'wins': 12, 'seen': 20}
# 3 0.5962 {'wins': 12, 'seen': 20}
# 4 0.5942 {'wins': 12, 'seen': 20}
# 5 0.5974 {'wins': 12, 'seen': 20}
# 6 0.5991 {'wins': 12, 'seen': 20}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ x _ _ _
# 4 x _ _ o _ _ _
# 3 o _ _ o _ _ _
# 2 x o _ x _ _ _
# 1 o x _ o _ _ x
#   A B C D E F G
#
# 0 0.5986 {'wins': 12, 'seen': 20}
# 1 0.5902 {'wins': 12, 'seen': 20}
# 2 0.6031 {'wins': 12, 'seen': 20}
# 3 0.5859 {'wins': 12, 'seen': 20}
# 4 0.5986 {'wins': 12, 'seen': 20}
# 5 0.5988 {'wins': 12, 'seen': 20}
# 6 0.5796 {'wins': 12, 'seen': 20}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ x _ _ _
# 4 x _ _ o _ _ _
# 3 o _ _ o _ _ _
# 2 x o _ x _ _ _
# 1 o x o o _ _ x
#   A B C D E F G
#
# 0 0.5921 {'wins': 12, 'seen': 20}
# 1 0.6007 {'wins': 12, 'seen': 20}
# 2 0.615 {'wins': 12, 'seen': 20}
# 3 0.6025 {'wins': 12, 'seen': 20}
# 4 0.591 {'wins': 12, 'seen': 20}
# 5 0.5998 {'wins': 12, 'seen': 20}
# 6 0.6013 {'wins': 12, 'seen': 20}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ x _ _ _
# 4 x _ _ o _ _ _
# 3 o _ _ o _ _ _
# 2 x o x x _ _ _
# 1 o x o o _ _ x
#   A B C D E F G
#
# 0 0.5967 {'wins': 12, 'seen': 20}
# 1 0.6007 {'wins': 12, 'seen': 20}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ x _ _ _
# 4 x _ _ o _ _ _
# 3 o _ o o _ _ _
# 2 x o x x _ _ _
# 1 o x o o _ _ x
#   A B C D E F G
#
# PLAYER WON /+
# 0 0.4782 {'wins': 268, 'seen': 584}
# 1 0.542 {'wins': 299, 'seen': 554}
# 2 0.601 {'wins': 346, 'seen': 575}
# 3 0.67 {'wins': 18856, 'seen': 28239}
# 4 0.5395 {'wins': 312, 'seen': 583}
# 5 0.4911 {'wins': 284, 'seen': 563}
# 6 0.4525 {'wins': 236, 'seen': 538}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 _ _ _ _ _ _ _
# 1 _ _ _ o _ _ _
#   A B C D E F G
#
# 0 0.1228 {'wins': 58, 'seen': 480}
# 1 0.2976 {'wins': 418, 'seen': 1413}
# 2 0.3104 {'wins': 1412, 'seen': 4434}
# 3 0.3668 {'wins': 5698, 'seen': 15890}
# 4 0.3125 {'wins': 1584, 'seen': 4916}
# 5 0.2625 {'wins': 190, 'seen': 714}
# 6 0.1951 {'wins': 99, 'seen': 512}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 _ _ _ x _ _ _
# 1 _ _ _ o _ _ _
#   A B C D E F G
#
# 0 0.6313 {'wins': 447, 'seen': 720}
# 1 0.5315 {'wins': 150, 'seen': 283}
# 2 0.6109 {'wins': 781, 'seen': 1295}
# 3 0.643 {'wins': 7044, 'seen': 10692}
# 4 0.6303 {'wins': 607, 'seen': 986}
# 5 0.601 {'wins': 561, 'seen': 929}
# 6 0.6151 {'wins': 678, 'seen': 1105}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ o _ _ _
# 2 _ _ _ x _ _ _
# 1 _ _ _ o _ _ _
#   A B C D E F G
#
# 0 0.3112 {'wins': 68, 'seen': 209}
# 1 0.345 {'wins': 2770, 'seen': 7840}
# 2 0.3328 {'wins': 217, 'seen': 657}
# 3 0.3044 {'wins': 60, 'seen': 203}
# 4 0.3384 {'wins': 192, 'seen': 596}
# 5 0.3257 {'wins': 269, 'seen': 811}
# 6 0.2763 {'wins': 148, 'seen': 496}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ o _ _ _
# 2 _ _ _ x _ _ _
# 1 _ x _ o _ _ _
#   A B C D E F G
#
# 0 0.4368 {'wins': 60, 'seen': 138}
# 1 0.6838 {'wins': 2972, 'seen': 4369}
# 2 0.4133 {'wins': 59, 'seen': 141}
# 3 0.6514 {'wins': 1535, 'seen': 2421}
# 4 0.5755 {'wins': 94, 'seen': 162}
# 5 0.5956 {'wins': 360, 'seen': 607}
# 6 0.5062 {'wins': 71, 'seen': 138}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ o _ _ _
# 2 _ o _ x _ _ _
# 1 _ x _ o _ _ _
#   A B C D E F G
#
# 0 0.2923 {'wins': 41, 'seen': 139}
# 1 0.2936 {'wins': 44, 'seen': 145}
# 2 0.3013 {'wins': 84, 'seen': 268}
# 3 0.3064 {'wins': 186, 'seen': 579}
# 4 0.335 {'wins': 267, 'seen': 805}
# 5 0.299 {'wins': 87, 'seen': 277}
# 6 0.3318 {'wins': 764, 'seen': 2276}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ o _ _ _
# 2 _ o _ x _ _ _
# 1 _ x _ o x _ _
#   A B C D E F G
#
# 0 0.6316 {'wins': 25, 'seen': 41}
# 1 0.5424 {'wins': 15, 'seen': 28}
# 2 0.511 {'wins': 24, 'seen': 47}
# 3 0.6887 {'wins': 500, 'seen': 734}
# 4 0.6621 {'wins': 21, 'seen': 32}
# 5 0.5118 {'wins': 40, 'seen': 76}
# 6 0.5857 {'wins': 25, 'seen': 44}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ o _ _ _
# 3 _ _ _ o _ _ _
# 2 _ o _ x _ _ _
# 1 _ x _ o x _ _
#   A B C D E F G
#
# 0 0.3636 {'wins': 83, 'seen': 228}
# 1 0.3541 {'wins': 43, 'seen': 120}
# 2 0.3553 {'wins': 48, 'seen': 136}
# 3 0.3669 {'wins': 97, 'seen': 264}
# 4 0.3292 {'wins': 13, 'seen': 41}
# 5 0.3052 {'wins': 21, 'seen': 67}
# 6 0.2558 {'wins': 19, 'seen': 75}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ x _ _ _
# 4 _ _ _ o _ _ _
# 3 _ _ _ o _ _ _
# 2 _ o _ x _ _ _
# 1 _ x _ o x _ _
#   A B C D E F G
#
# 0 0.5997 {'wins': 16, 'seen': 27}
# 1 0.5387 {'wins': 12, 'seen': 22}
# 2 0.49 {'wins': 12, 'seen': 24}
# 3 0.617 {'wins': 16, 'seen': 26}
# 4 0.6794 {'wins': 160, 'seen': 239}
# 5 0.5609 {'wins': 14, 'seen': 25}
# 6 0.5916 {'wins': 15, 'seen': 25}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ x _ _ _
# 4 _ _ _ o _ _ _
# 3 _ _ _ o _ _ _
# 2 _ o _ x o _ _
# 1 _ x _ o x _ _
#   A B C D E F G
#
# 0 0.4185 {'wins': 18, 'seen': 44}
# 1 0.4319 {'wins': 26, 'seen': 60}
# 2 0.4145 {'wins': 14, 'seen': 33}
# 3 0.4327 {'wins': 21, 'seen': 49}
# 4 0.4387 {'wins': 24, 'seen': 57}
# 5 0.4424 {'wins': 36, 'seen': 82}
# 6 0.4285 {'wins': 16, 'seen': 37}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ x _ _ _
# 4 _ _ _ o _ _ _
# 3 _ _ _ o _ _ _
# 2 _ o _ x o _ _
# 1 _ x _ o x x _
#   A B C D E F G
#
# 0 0.5738 {'wins': 13, 'seen': 22}
# 1 0.5901 {'wins': 15, 'seen': 25}
# 2 0.5928 {'wins': 12, 'seen': 20}
# 3 0.5947 {'wins': 13, 'seen': 22}
# 4 0.5726 {'wins': 13, 'seen': 22}
# 5 0.5822 {'wins': 34, 'seen': 56}
# 6 0.6654 {'wins': 31, 'seen': 46}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ x _ _ _
# 4 _ _ _ o _ _ _
# 3 _ _ _ o _ _ _
# 2 _ o _ x o _ _
# 1 _ x _ o x x o
#   A B C D E F G
#
# 0 0.5472 {'wins': 13, 'seen': 24}
# 1 0.5494 {'wins': 13, 'seen': 23}
# 2 0.5657 {'wins': 12, 'seen': 22}
# 3 0.5441 {'wins': 14, 'seen': 26}
# 4 0.5333 {'wins': 15, 'seen': 27}
# 5 0.5687 {'wins': 12, 'seen': 21}
# 6 0.5448 {'wins': 13, 'seen': 24}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ x _ _ _
# 4 _ _ _ o _ _ _
# 3 _ _ _ o _ _ _
# 2 _ o _ x o x _
# 1 _ x _ o x x o
#   A B C D E F G
#
# 0 0.6186 {'wins': 13, 'seen': 21}
# 1 0.6096 {'wins': 12, 'seen': 20}
# 2 0.6092 {'wins': 12, 'seen': 20}
# 3 0.5685 {'wins': 12, 'seen': 21}
# 4 0.594 {'wins': 12, 'seen': 20}
# 5 0.6197 {'wins': 12, 'seen': 20}
# 6 0.5873 {'wins': 12, 'seen': 20}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ x _ _ _
# 4 _ _ _ o _ _ _
# 3 _ _ _ o _ o _
# 2 _ o _ x o x _
# 1 _ x _ o x x o
#   A B C D E F G
#
# 0 0.5848 {'wins': 12, 'seen': 20}
# 1 0.5995 {'wins': 12, 'seen': 20}
# 2 0.6043 {'wins': 12, 'seen': 20}
# 3 0.5792 {'wins': 12, 'seen': 20}
# 4 0.5897 {'wins': 12, 'seen': 20}
# 5 0.6148 {'wins': 12, 'seen': 20}
# 6 0.6064 {'wins': 12, 'seen': 20}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ x _ _ _
# 4 _ _ _ o _ x _
# 3 _ _ _ o _ o _
# 2 _ o _ x o x _
# 1 _ x _ o x x o
#   A B C D E F G
#
# 0 0.5938 {'wins': 12, 'seen': 20}
# 1 0.6126 {'wins': 12, 'seen': 20}
# 2 0.6134 {'wins': 12, 'seen': 20}
# 3 0.6028 {'wins': 12, 'seen': 20}
# 4 0.6114 {'wins': 12, 'seen': 20}
# 5 0.6197 {'wins': 12, 'seen': 20}
# 6 0.5961 {'wins': 12, 'seen': 20}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ x _ o _
# 4 _ _ _ o _ x _
# 3 _ _ _ o _ o _
# 2 _ o _ x o x _
# 1 _ x _ o x x o
#   A B C D E F G
#
# 0 0.5931 {'wins': 12, 'seen': 20}
# 1 0.5908 {'wins': 12, 'seen': 20}
# 2 0.5998 {'wins': 12, 'seen': 20}
# 3 0.5932 {'wins': 12, 'seen': 20}
# 4 0.5965 {'wins': 12, 'seen': 20}
# 5 0.6074 {'wins': 12, 'seen': 20}
# 6 0.6135 {'wins': 12, 'seen': 20}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ x _ o _
# 4 _ _ _ o _ x _
# 3 _ _ _ o _ o _
# 2 _ o _ x o x x
# 1 _ x _ o x x o
#   A B C D E F G
#
# 0 0.5991 {'wins': 12, 'seen': 20}
# 1 0.6102 {'wins': 12, 'seen': 20}
# 2 0.6134 {'wins': 12, 'seen': 20}
# 3 0.6044 {'wins': 12, 'seen': 20}
# 4 0.605 {'wins': 12, 'seen': 20}
# 5 0.5875 {'wins': 12, 'seen': 20}
# 6 0.6003 {'wins': 12, 'seen': 20}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ x _ o _
# 4 _ _ _ o _ x _
# 3 _ _ _ o _ o _
# 2 _ o _ x o x x
# 1 _ x o o x x o
#   A B C D E F G
#
# 0 0.6038 {'wins': 12, 'seen': 20}
# 1 0.5782 {'wins': 12, 'seen': 20}
# 2 0.5886 {'wins': 12, 'seen': 20}
# 3 0.6039 {'wins': 12, 'seen': 20}
# 4 0.594 {'wins': 12, 'seen': 20}
# 5 0.5971 {'wins': 12, 'seen': 20}
# 6 0.6034 {'wins': 12, 'seen': 20}
# BLACK TO MOVE
# 6 _ _ _ x _ _ _
# 5 _ _ _ x _ o _
# 4 _ _ _ o _ x _
# 3 _ _ _ o _ o _
# 2 _ o _ x o x x
# 1 _ x o o x x o
#   A B C D E F G
#
# 0 0.6149 {'wins': 12, 'seen': 20}
# 1 0.6112 {'wins': 12, 'seen': 20}
# 2 0.609 {'wins': 12, 'seen': 20}
# 4 0.6059 {'wins': 12, 'seen': 20}
# 5 0.6102 {'wins': 12, 'seen': 20}
# 6 0.5971 {'wins': 12, 'seen': 20}
# WHITE TO MOVE
# 6 _ _ _ x _ _ _
# 5 _ _ _ x _ o _
# 4 _ _ _ o _ x _
# 3 _ _ _ o _ o _
# 2 _ o _ x o x x
# 1 o x o o x x o
#   A B C D E F G
#
# 0 0.5873 {'wins': 12, 'seen': 20}
# 1 0.6122 {'wins': 12, 'seen': 20}
# 2 0.6033 {'wins': 12, 'seen': 20}
# 4 0.6065 {'wins': 12, 'seen': 20}
# 5 0.6269 {'wins': 12, 'seen': 20}
# 6 0.587 {'wins': 12, 'seen': 20}
# BLACK TO MOVE
# 6 _ _ _ x _ x _
# 5 _ _ _ x _ o _
# 4 _ _ _ o _ x _
# 3 _ _ _ o _ o _
# 2 _ o _ x o x x
# 1 o x o o x x o
#   A B C D E F G
#
# 0 0.6158 {'wins': 12, 'seen': 20}
# 1 0.5984 {'wins': 12, 'seen': 20}
# 2 0.6003 {'wins': 12, 'seen': 20}
# 4 0.5847 {'wins': 12, 'seen': 20}
# 6 0.6101 {'wins': 12, 'seen': 20}
# WHITE TO MOVE
# 6 _ _ _ x _ x _
# 5 _ _ _ x _ o _
# 4 _ _ _ o _ x _
# 3 _ _ _ o _ o _
# 2 o o _ x o x x
# 1 o x o o x x o
#   A B C D E F G
#
# 0 0.6171 {'wins': 12, 'seen': 20}
# 1 0.5917 {'wins': 12, 'seen': 20}
# 2 0.6028 {'wins': 12, 'seen': 20}
# 4 0.5911 {'wins': 12, 'seen': 20}
# 6 0.5953 {'wins': 12, 'seen': 20}
# BLACK TO MOVE
# 6 _ _ _ x _ x _
# 5 _ _ _ x _ o _
# 4 _ _ _ o _ x _
# 3 x _ _ o _ o _
# 2 o o _ x o x x
# 1 o x o o x x o
#   A B C D E F G
#
# 0 0.5988 {'wins': 12, 'seen': 20}
# 1 0.5868 {'wins': 12, 'seen': 20}
# 2 0.5905 {'wins': 12, 'seen': 20}
# 4 0.593 {'wins': 12, 'seen': 20}
# 6 0.6059 {'wins': 12, 'seen': 20}
# WHITE TO MOVE
# 6 _ _ _ x _ x _
# 5 _ _ _ x _ o _
# 4 _ _ _ o _ x _
# 3 x _ _ o _ o o
# 2 o o _ x o x x
# 1 o x o o x x o
#   A B C D E F G
#
# 0 0.5922 {'wins': 12, 'seen': 20}
# 1 0.6064 {'wins': 12, 'seen': 20}
# 2 0.6074 {'wins': 12, 'seen': 20}
# 4 0.6013 {'wins': 12, 'seen': 20}
# 6 0.603 {'wins': 12, 'seen': 20}
# BLACK TO MOVE
# 6 _ _ _ x _ x _
# 5 _ _ _ x _ o _
# 4 _ _ _ o _ x _
# 3 x _ _ o _ o o
# 2 o o x x o x x
# 1 o x o o x x o
#   A B C D E F G
#
# 0 0.5854 {'wins': 12, 'seen': 20}
# 1 0.597 {'wins': 12, 'seen': 20}
# WHITE TO MOVE
# 6 _ _ _ x _ x _
# 5 _ _ _ x _ o _
# 4 _ _ _ o _ x _
# 3 x _ o o _ o o
# 2 o o x x o x x
# 1 o x o o x x o
#   A B C D E F G
#
# PLAYER WON /+
# 0 0.4466 {'wins': 268, 'seen': 584}
# 1 0.5347 {'wins': 299, 'seen': 554}
# 2 0.5974 {'wins': 346, 'seen': 575}
# 3 0.6709 {'wins': 18857, 'seen': 28240}
# 4 0.5327 {'wins': 312, 'seen': 583}
# 5 0.4834 {'wins': 284, 'seen': 563}
# 6 0.4326 {'wins': 236, 'seen': 538}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 _ _ _ _ _ _ _
# 1 _ _ _ o _ _ _
#   A B C D E F G
#
# 0 0.1252 {'wins': 58, 'seen': 480}
# 1 0.2831 {'wins': 418, 'seen': 1413}
# 2 0.3096 {'wins': 1412, 'seen': 4434}
# 3 0.361 {'wins': 5698, 'seen': 15891}
# 4 0.3161 {'wins': 1584, 'seen': 4916}
# 5 0.2808 {'wins': 190, 'seen': 714}
# 6 0.1985 {'wins': 99, 'seen': 512}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 _ _ _ x _ _ _
# 1 _ _ _ o _ _ _
#   A B C D E F G
#
# 0 0.6106 {'wins': 447, 'seen': 720}
# 1 0.5328 {'wins': 150, 'seen': 283}
# 2 0.6258 {'wins': 781, 'seen': 1295}
# 3 0.6638 {'wins': 7045, 'seen': 10693}
# 4 0.606 {'wins': 607, 'seen': 986}
# 5 0.5905 {'wins': 561, 'seen': 929}
# 6 0.6142 {'wins': 678, 'seen': 1105}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ o _ _ _
# 2 _ _ _ x _ _ _
# 1 _ _ _ o _ _ _
#   A B C D E F G
#
# 0 0.3348 {'wins': 68, 'seen': 209}
# 1 0.3544 {'wins': 2770, 'seen': 7841}
# 2 0.3157 {'wins': 217, 'seen': 657}
# 3 0.2882 {'wins': 60, 'seen': 203}
# 4 0.3295 {'wins': 192, 'seen': 596}
# 5 0.3366 {'wins': 269, 'seen': 811}
# 6 0.2997 {'wins': 148, 'seen': 496}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ o _ _ _
# 2 _ _ _ x _ _ _
# 1 _ x _ o _ _ _
#   A B C D E F G
#
# 0 0.4337 {'wins': 60, 'seen': 138}
# 1 0.6789 {'wins': 2973, 'seen': 4370}
# 2 0.3982 {'wins': 59, 'seen': 141}
# 3 0.6232 {'wins': 1535, 'seen': 2421}
# 4 0.5791 {'wins': 94, 'seen': 162}
# 5 0.5944 {'wins': 360, 'seen': 607}
# 6 0.5099 {'wins': 71, 'seen': 138}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ o _ _ _
# 2 _ o _ x _ _ _
# 1 _ x _ o _ _ _
#   A B C D E F G
#
# 0 0.2809 {'wins': 41, 'seen': 139}
# 1 0.3036 {'wins': 44, 'seen': 145}
# 2 0.3062 {'wins': 84, 'seen': 268}
# 3 0.3209 {'wins': 186, 'seen': 579}
# 4 0.3343 {'wins': 267, 'seen': 806}
# 5 0.3151 {'wins': 87, 'seen': 277}
# 6 0.3289 {'wins': 764, 'seen': 2276}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ o _ _ _
# 2 _ o _ x _ _ _
# 1 _ x _ o x _ _
#   A B C D E F G
#
# 0 0.5996 {'wins': 25, 'seen': 41}
# 1 0.521 {'wins': 15, 'seen': 28}
# 2 0.505 {'wins': 24, 'seen': 47}
# 3 0.6824 {'wins': 501, 'seen': 735}
# 4 0.6671 {'wins': 21, 'seen': 32}
# 5 0.525 {'wins': 40, 'seen': 76}
# 6 0.5672 {'wins': 25, 'seen': 44}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ o _ _ _
# 3 _ _ _ o _ _ _
# 2 _ o _ x _ _ _
# 1 _ x _ o x _ _
#   A B C D E F G
#
# 0 0.36 {'wins': 83, 'seen': 228}
# 1 0.3462 {'wins': 43, 'seen': 120}
# 2 0.361 {'wins': 48, 'seen': 136}
# 3 0.3732 {'wins': 97, 'seen': 265}
# 4 0.3105 {'wins': 13, 'seen': 41}
# 5 0.2945 {'wins': 21, 'seen': 67}
# 6 0.2513 {'wins': 19, 'seen': 75}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ x _ _ _
# 4 _ _ _ o _ _ _
# 3 _ _ _ o _ _ _
# 2 _ o _ x _ _ _
# 1 _ x _ o x _ _
#   A B C D E F G
#
# 0 0.6104 {'wins': 16, 'seen': 27}
# 1 0.5382 {'wins': 12, 'seen': 22}
# 2 0.509 {'wins': 12, 'seen': 24}
# 3 0.6126 {'wins': 16, 'seen': 26}
# 4 0.6728 {'wins': 161, 'seen': 240}
# 5 0.5769 {'wins': 14, 'seen': 25}
# 6 0.5846 {'wins': 15, 'seen': 25}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ x _ _ _
# 4 _ _ _ o _ _ _
# 3 _ _ _ o _ _ _
# 2 _ o _ x o _ _
# 1 _ x _ o x _ _
#   A B C D E F G
#
# 0 0.4131 {'wins': 18, 'seen': 44}
# 1 0.4354 {'wins': 26, 'seen': 60}
# 2 0.4317 {'wins': 14, 'seen': 33}
# 3 0.427 {'wins': 21, 'seen': 49}
# 4 0.402 {'wins': 24, 'seen': 57}
# 5 0.4426 {'wins': 36, 'seen': 83}
# 6 0.4236 {'wins': 16, 'seen': 37}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ x _ _ _
# 4 _ _ _ o _ _ _
# 3 _ _ _ o _ _ _
# 2 _ o _ x o _ _
# 1 _ x _ o x x _
#   A B C D E F G
#
# 0 0.5873 {'wins': 13, 'seen': 22}
# 1 0.5892 {'wins': 15, 'seen': 25}
# 2 0.5998 {'wins': 12, 'seen': 20}
# 3 0.5786 {'wins': 13, 'seen': 22}
# 4 0.5944 {'wins': 13, 'seen': 22}
# 5 0.6204 {'wins': 34, 'seen': 56}
# 6 0.6815 {'wins': 32, 'seen': 47}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ x _ _ _
# 4 _ _ _ o _ _ _
# 3 _ _ _ o _ _ _
# 2 _ o _ x o _ _
# 1 _ x _ o x x o
#   A B C D E F G
#
# 0 0.5459 {'wins': 13, 'seen': 24}
# 1 0.5787 {'wins': 13, 'seen': 23}
# 2 0.547 {'wins': 12, 'seen': 22}
# 3 0.5474 {'wins': 14, 'seen': 26}
# 4 0.5517 {'wins': 15, 'seen': 27}
# 5 0.5455 {'wins': 12, 'seen': 22}
# 6 0.5433 {'wins': 13, 'seen': 24}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ x _ _ _
# 4 _ _ _ o _ _ _
# 3 _ x _ o _ _ _
# 2 _ o _ x o _ _
# 1 _ x _ o x x o
#   A B C D E F G
#
# 0 0.5945 {'wins': 12, 'seen': 20}
# 1 0.5905 {'wins': 12, 'seen': 20}
# 2 0.6157 {'wins': 12, 'seen': 20}
# 3 0.5814 {'wins': 12, 'seen': 21}
# 4 0.604 {'wins': 12, 'seen': 20}
# 5 0.5858 {'wins': 12, 'seen': 20}
# 6 0.6525 {'wins': 14, 'seen': 22}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ x _ _ _
# 4 _ _ _ o _ _ _
# 3 _ x _ o _ _ _
# 2 _ o _ x o _ o
# 1 _ x _ o x x o
#   A B C D E F G
#
# 0 0.5965 {'wins': 12, 'seen': 20}
# 1 0.5682 {'wins': 12, 'seen': 21}
# 2 0.5955 {'wins': 12, 'seen': 20}
# 3 0.5761 {'wins': 12, 'seen': 21}
# 4 0.579 {'wins': 12, 'seen': 21}
# 5 0.6198 {'wins': 12, 'seen': 20}
# 6 0.6116 {'wins': 12, 'seen': 20}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ x _ _ _
# 4 _ _ _ o _ _ _
# 3 _ x _ o _ _ _
# 2 _ o _ x o x o
# 1 _ x _ o x x o
#   A B C D E F G
#
# 0 0.6014 {'wins': 12, 'seen': 20}
# 1 0.6008 {'wins': 12, 'seen': 20}
# 2 0.5903 {'wins': 12, 'seen': 20}
# 3 0.5971 {'wins': 12, 'seen': 20}
# 4 0.5994 {'wins': 12, 'seen': 20}
# 5 0.6152 {'wins': 12, 'seen': 20}
# 6 0.6031 {'wins': 12, 'seen': 20}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ x _ _ _
# 4 _ _ _ o _ _ _
# 3 _ x _ o _ o _
# 2 _ o _ x o x o
# 1 _ x _ o x x o
#   A B C D E F G
#
# 0 0.6142 {'wins': 12, 'seen': 20}
# 1 0.6058 {'wins': 12, 'seen': 20}
# 2 0.6129 {'wins': 12, 'seen': 20}
# 3 0.5995 {'wins': 12, 'seen': 20}
# 4 0.5934 {'wins': 12, 'seen': 20}
# 5 0.6084 {'wins': 12, 'seen': 20}
# 6 0.5981 {'wins': 12, 'seen': 20}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ x _ _ _
# 4 _ _ _ o _ _ _
# 3 _ x _ o _ o _
# 2 _ o _ x o x o
# 1 x x _ o x x o
#   A B C D E F G
#
# 0 0.6053 {'wins': 12, 'seen': 20}
# 1 0.5968 {'wins': 12, 'seen': 20}
# 2 0.5857 {'wins': 12, 'seen': 20}
# 3 0.62 {'wins': 12, 'seen': 20}
# 4 0.5857 {'wins': 12, 'seen': 20}
# 5 0.6024 {'wins': 12, 'seen': 20}
# 6 0.5972 {'wins': 12, 'seen': 20}
# WHITE TO MOVE
# 6 _ _ _ o _ _ _
# 5 _ _ _ x _ _ _
# 4 _ _ _ o _ _ _
# 3 _ x _ o _ o _
# 2 _ o _ x o x o
# 1 x x _ o x x o
#   A B C D E F G
#
# 0 0.5889 {'wins': 12, 'seen': 20}
# 1 0.5997 {'wins': 12, 'seen': 20}
# 2 0.596 {'wins': 12, 'seen': 20}
# 4 0.5924 {'wins': 12, 'seen': 20}
# 5 0.5996 {'wins': 12, 'seen': 20}
# 6 0.579 {'wins': 12, 'seen': 20}
# BLACK TO MOVE
# 6 _ _ _ o _ _ _
# 5 _ _ _ x _ _ _
# 4 _ x _ o _ _ _
# 3 _ x _ o _ o _
# 2 _ o _ x o x o
# 1 x x _ o x x o
#   A B C D E F G
#
# 0 0.609 {'wins': 12, 'seen': 20}
# 1 0.6065 {'wins': 12, 'seen': 20}
# 2 0.5904 {'wins': 12, 'seen': 20}
# 4 0.6033 {'wins': 12, 'seen': 20}
# 5 0.5987 {'wins': 12, 'seen': 20}
# 6 0.6119 {'wins': 12, 'seen': 20}
# WHITE TO MOVE
# 6 _ _ _ o _ _ _
# 5 _ _ _ x _ _ _
# 4 _ x _ o _ _ _
# 3 _ x _ o _ o o
# 2 _ o _ x o x o
# 1 x x _ o x x o
#   A B C D E F G
#
# 0 0.6079 {'wins': 12, 'seen': 20}
# 1 0.6014 {'wins': 12, 'seen': 20}
# 2 0.6257 {'wins': 12, 'seen': 20}
# 4 0.5911 {'wins': 12, 'seen': 20}
# 5 0.6145 {'wins': 12, 'seen': 20}
# 6 0.5971 {'wins': 12, 'seen': 20}
# BLACK TO MOVE
# 6 _ _ _ o _ _ _
# 5 _ _ _ x _ _ _
# 4 _ x _ o _ _ _
# 3 _ x _ o _ o o
# 2 _ o _ x o x o
# 1 x x x o x x o
#   A B C D E F G
#
# 0 0.58 {'wins': 12, 'seen': 20}
# 1 0.6016 {'wins': 12, 'seen': 20}
# 2 0.5999 {'wins': 12, 'seen': 20}
# WHITE TO MOVE
# 6 _ _ _ o _ _ _
# 5 _ _ _ x _ _ _
# 4 _ x _ o _ _ _
# 3 _ x _ o o o o
# 2 _ o _ x o x o
# 1 x x x o x x o
#   A B C D E F G
#
# PLAYER WON -
# False

# %%
table = ai.table

# %%
# b.print_board(list((556206917161, 50538708)), 0)

# %%
seen_tot = 0
wins_tot = 0
for v in table.values():
    seen_tot += v['seen'] - 20
    wins_tot += v['wins'] - 10

#     print(v,k)

print(seen_tot, wins_tot, float(wins_tot) / seen_tot)
avg_seen = seen_tot / len(table)

print(avg_seen)

# %%
ai.Run(1,0,True)

# %%
x = []
for u in range(1000):
    x.append( np.random.randint(0,6))

# %%
max(x)

# %%
min(x)

# %%
\
