# %%
from board import Board
import random
import pickle
from Table_ai import Table_ai
import numpy as np

# %%
ai = Table_ai()
b = Board()

# %%
ai.table
# Out:
# {}

# %%
ai.Run(5000,.9)
ai.Run(1, 0, True)
ai.Run(30000, .7)
ai.Run(30000, .5)
print("\n\nAfter 0.1 \n\n")
print("----------------------------")
print("----------------------------")
print("----------------------------")


ai.Run(1, 0, True)
ai.Run(100000, .2)
ai.Run(100000, 0.1)
ai.Run(1000, 0.5)
ai.Run(1000000, 0.05)
print("\n\nFINAL\n\n")
print("----------------------------")
print("----------------------------")
print("----------------------------")

table = ai.Run(3, 0, True)
# Out:
# 5000 0.9 False
# 1 0 True
# 0 0.4812 {'wins': 22, 'seen': 41}
# 1 0.5483 {'wins': 22, 'seen': 40}
# 2 0.5251 {'wins': 21, 'seen': 37}
# 3 0.5608 {'wins': 18, 'seen': 33}
# 4 0.5902 {'wins': 27, 'seen': 46}
# 5 0.5377 {'wins': 26, 'seen': 46}
# 6 0.6493 {'wins': 28, 'seen': 43}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 _ _ _ _ _ _ _
# 1 _ _ _ _ _ _ o
#   A B C D E F G
#
# 0 0.7229 {'wins': 16, 'seen': 22}
# 1 0.6114 {'wins': 18, 'seen': 29}
# 2 0.7745 {'wins': 16, 'seen': 21}
# 3 0.6921 {'wins': 16, 'seen': 23}
# 4 0.7048 {'wins': 17, 'seen': 24}
# 5 0.6875 {'wins': 16, 'seen': 22}
# 6 0.7516 {'wins': 16, 'seen': 22}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 _ _ _ _ _ _ _
# 1 _ _ x _ _ _ o
#   A B C D E F G
#
# 0 0.7099 {'wins': 15, 'seen': 20}
# 1 0.7575 {'wins': 15, 'seen': 20}
# 2 0.7592 {'wins': 15, 'seen': 20}
# 3 0.7497 {'wins': 16, 'seen': 21}
# 4 0.7389 {'wins': 15, 'seen': 20}
# 5 0.7524 {'wins': 15, 'seen': 20}
# 6 0.7326 {'wins': 15, 'seen': 21}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 _ _ o _ _ _ _
# 1 _ _ x _ _ _ o
#   A B C D E F G
#
# 0 0.7301 {'wins': 15, 'seen': 20}
# 1 0.7478 {'wins': 15, 'seen': 20}
# 2 0.7402 {'wins': 15, 'seen': 20}
# 3 0.7367 {'wins': 15, 'seen': 20}
# 4 0.7746 {'wins': 15, 'seen': 20}
# 5 0.7073 {'wins': 15, 'seen': 20}
# 6 0.7701 {'wins': 15, 'seen': 20}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 _ _ o _ _ _ _
# 1 _ _ x _ x _ o
#   A B C D E F G
#
# 0 0.7635 {'wins': 15, 'seen': 20}
# 1 0.7756 {'wins': 15, 'seen': 20}
# 2 0.7671 {'wins': 15, 'seen': 20}
# 3 0.7689 {'wins': 15, 'seen': 20}
# 4 0.7437 {'wins': 15, 'seen': 20}
# 5 0.7409 {'wins': 15, 'seen': 20}
# 6 0.7677 {'wins': 15, 'seen': 20}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 _ _ o _ _ _ _
# 1 _ o x _ x _ o
#   A B C D E F G
#
# 0 0.7687 {'wins': 15, 'seen': 20}
# 1 0.7487 {'wins': 15, 'seen': 20}
# 2 0.7446 {'wins': 15, 'seen': 20}
# 3 0.7756 {'wins': 15, 'seen': 20}
# 4 0.7592 {'wins': 15, 'seen': 20}
# 5 0.7641 {'wins': 15, 'seen': 20}
# 6 0.7478 {'wins': 15, 'seen': 20}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 _ _ o _ _ _ _
# 1 _ o x x x _ o
#   A B C D E F G
#
# 0 0.7203 {'wins': 15, 'seen': 20}
# 1 0.7349 {'wins': 15, 'seen': 20}
# 2 0.7466 {'wins': 15, 'seen': 20}
# 3 0.7156 {'wins': 15, 'seen': 20}
# 4 0.7379 {'wins': 15, 'seen': 20}
# 5 0.7521 {'wins': 15, 'seen': 20}
# 6 0.7748 {'wins': 15, 'seen': 20}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 _ _ o _ _ _ o
# 1 _ o x x x _ o
#   A B C D E F G
#
# 0 0.7515 {'wins': 15, 'seen': 20}
# 1 0.7627 {'wins': 15, 'seen': 20}
# 2 0.7486 {'wins': 15, 'seen': 20}
# 3 0.7853 {'wins': 15, 'seen': 20}
# 4 0.752 {'wins': 15, 'seen': 20}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 _ _ o _ _ _ o
# 1 _ o x x x x o
#   A B C D E F G
#
# PLAYER WON -
# 30000 0.7 False
# 30000 0.5 False
#
#
# After 0.1
#
#
# ----------------------------
# ----------------------------
# ----------------------------
# 1 0 True
# 0 0.5182 {'wins': 4057, 'seen': 8566}
# 1 0.4336 {'wins': 1175, 'seen': 2794}
# 2 0.3923 {'wins': 1059, 'seen': 2684}
# 3 0.2663 {'wins': 705, 'seen': 2691}
# 4 0.4467 {'wins': 1067, 'seen': 2655}
# 5 0.3997 {'wins': 1189, 'seen': 2858}
# 6 0.5113 {'wins': 4165, 'seen': 8821}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 _ _ _ _ _ _ _
# 1 o _ _ _ _ _ _
#   A B C D E F G
#
# 0 0.5451 {'wins': 686, 'seen': 1248}
# 1 0.5186 {'wins': 392, 'seen': 780}
# 2 0.4378 {'wins': 300, 'seen': 686}
# 3 0.3502 {'wins': 258, 'seen': 713}
# 4 0.5472 {'wins': 517, 'seen': 972}
# 5 0.5209 {'wins': 417, 'seen': 798}
# 6 0.6051 {'wins': 2039, 'seen': 3489}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 _ _ _ _ _ _ _
# 1 o _ _ _ _ _ x
#   A B C D E F G
#
# 0 0.4337 {'wins': 342, 'seen': 759}
# 1 0.4291 {'wins': 199, 'seen': 466}
# 2 0.3991 {'wins': 126, 'seen': 329}
# 3 0.2427 {'wins': 96, 'seen': 392}
# 4 0.3977 {'wins': 138, 'seen': 339}
# 5 0.4532 {'wins': 303, 'seen': 676}
# 6 0.476 {'wins': 516, 'seen': 1065}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 _ _ _ _ _ _ o
# 1 o _ _ _ _ _ x
#   A B C D E F G
#
# 0 0.5991 {'wins': 237, 'seen': 400}
# 1 0.5456 {'wins': 85, 'seen': 156}
# 2 0.5629 {'wins': 54, 'seen': 97}
# 3 0.4631 {'wins': 51, 'seen': 111}
# 4 0.4652 {'wins': 53, 'seen': 112}
# 5 0.5108 {'wins': 47, 'seen': 94}
# 6 0.5545 {'wins': 122, 'seen': 215}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 x _ _ _ _ _ o
# 1 o _ _ _ _ _ x
#   A B C D E F G
#
# 0 0.5347 {'wins': 64, 'seen': 120}
# 1 0.5694 {'wins': 63, 'seen': 113}
# 2 0.4268 {'wins': 28, 'seen': 64}
# 3 0.3789 {'wins': 24, 'seen': 61}
# 4 0.4775 {'wins': 33, 'seen': 69}
# 5 0.4294 {'wins': 27, 'seen': 62}
# 6 0.5389 {'wins': 47, 'seen': 87}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 x _ _ _ _ _ o
# 1 o o _ _ _ _ x
#   A B C D E F G
#
# 0 0.7071 {'wins': 28, 'seen': 42}
# 1 0.5896 {'wins': 22, 'seen': 38}
# 2 0.594 {'wins': 28, 'seen': 47}
# 3 0.6127 {'wins': 23, 'seen': 36}
# 4 0.5798 {'wins': 21, 'seen': 37}
# 5 0.72 {'wins': 25, 'seen': 35}
# 6 0.6898 {'wins': 31, 'seen': 44}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 x _ _ _ _ _ o
# 1 o o _ _ _ x x
#   A B C D E F G
#
# 0 0.6837 {'wins': 22, 'seen': 32}
# 1 0.6789 {'wins': 16, 'seen': 23}
# 2 0.7013 {'wins': 15, 'seen': 22}
# 3 0.686 {'wins': 15, 'seen': 22}
# 4 0.6218 {'wins': 15, 'seen': 23}
# 5 0.6693 {'wins': 16, 'seen': 24}
# 6 0.7027 {'wins': 15, 'seen': 22}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ o
# 2 x _ _ _ _ _ o
# 1 o o _ _ _ x x
#   A B C D E F G
#
# 0 0.7493 {'wins': 16, 'seen': 21}
# 1 0.7693 {'wins': 18, 'seen': 24}
# 2 0.7421 {'wins': 16, 'seen': 22}
# 3 0.7837 {'wins': 15, 'seen': 20}
# 4 0.7569 {'wins': 15, 'seen': 20}
# 5 0.7493 {'wins': 15, 'seen': 20}
# 6 0.7124 {'wins': 15, 'seen': 20}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ o
# 2 x _ _ _ _ _ o
# 1 o o _ x _ x x
#   A B C D E F G
#
# 0 0.7913 {'wins': 16, 'seen': 21}
# 1 0.7389 {'wins': 15, 'seen': 20}
# 2 0.7324 {'wins': 15, 'seen': 20}
# 3 0.7263 {'wins': 15, 'seen': 20}
# 4 0.7217 {'wins': 15, 'seen': 21}
# 5 0.7574 {'wins': 15, 'seen': 20}
# 6 0.7492 {'wins': 15, 'seen': 20}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 o _ _ _ _ _ o
# 2 x _ _ _ _ _ o
# 1 o o _ x _ x x
#   A B C D E F G
#
# 0 0.7419 {'wins': 15, 'seen': 20}
# 1 0.7641 {'wins': 15, 'seen': 20}
# 2 0.7685 {'wins': 15, 'seen': 20}
# 3 0.7417 {'wins': 15, 'seen': 20}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 o _ _ _ _ _ o
# 2 x _ _ _ _ _ o
# 1 o o _ x x x x
#   A B C D E F G
#
# PLAYER WON -
# 100000 0.2 False
# 100000 0.1 False
# 1000 0.5 False
# 1000000 0.05 False
#
#
# FINAL
#
#
# ----------------------------
# ----------------------------
# ----------------------------
# 3 0 True
# 0 0.4409 {'wins': 8272, 'seen': 18546}
# 1 0.4287 {'wins': 1547, 'seen': 3745}
# 2 0.3883 {'wins': 1174, 'seen': 3075}
# 3 0.2692 {'wins': 755, 'seen': 3005}
# 4 0.394 {'wins': 1235, 'seen': 3130}
# 5 0.4292 {'wins': 1448, 'seen': 3542}
# 6 0.4175 {'wins': 7082, 'seen': 16201}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 _ _ _ _ _ _ _
# 1 o _ _ _ _ _ _
#   A B C D E F G
#
# 0 0.5629 {'wins': 1560, 'seen': 2783}
# 1 0.489 {'wins': 487, 'seen': 972}
# 2 0.4721 {'wins': 378, 'seen': 836}
# 3 0.3459 {'wins': 323, 'seen': 877}
# 4 0.5473 {'wins': 678, 'seen': 1285}
# 5 0.4891 {'wins': 550, 'seen': 1035}
# 6 0.5811 {'wins': 6398, 'seen': 10878}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 _ _ _ _ _ _ _
# 1 o _ _ _ _ _ x
#   A B C D E F G
#
# 0 0.4287 {'wins': 1063, 'seen': 2486}
# 1 0.37 {'wins': 298, 'seen': 754}
# 2 0.3593 {'wins': 148, 'seen': 421}
# 3 0.2332 {'wins': 123, 'seen': 508}
# 4 0.3908 {'wins': 207, 'seen': 539}
# 5 0.3674 {'wins': 668, 'seen': 1639}
# 6 0.4577 {'wins': 2278, 'seen': 5150}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 _ _ _ _ _ _ o
# 1 o _ _ _ _ _ x
#   A B C D E F G
#
# 0 0.6068 {'wins': 1173, 'seen': 1982}
# 1 0.5117 {'wins': 117, 'seen': 221}
# 2 0.5211 {'wins': 117, 'seen': 232}
# 3 0.3398 {'wins': 62, 'seen': 177}
# 4 0.4946 {'wins': 79, 'seen': 170}
# 5 0.4739 {'wins': 78, 'seen': 153}
# 6 0.58 {'wins': 1346, 'seen': 2335}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 x _ _ _ _ _ o
# 1 o _ _ _ _ _ x
#   A B C D E F G
#
# 0 0.4635 {'wins': 472, 'seen': 1049}
# 1 0.4261 {'wins': 168, 'seen': 402}
# 2 0.4019 {'wins': 43, 'seen': 106}
# 3 0.3073 {'wins': 26, 'seen': 83}
# 4 0.4472 {'wins': 62, 'seen': 154}
# 5 0.4232 {'wins': 140, 'seen': 346}
# 6 0.4281 {'wins': 120, 'seen': 276}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 o _ _ _ _ _ _
# 2 x _ _ _ _ _ o
# 1 o _ _ _ _ _ x
#   A B C D E F G
#
# 0 0.5793 {'wins': 360, 'seen': 601}
# 1 0.5878 {'wins': 42, 'seen': 77}
# 2 0.5615 {'wins': 50, 'seen': 88}
# 3 0.5207 {'wins': 23, 'seen': 44}
# 4 0.4845 {'wins': 34, 'seen': 65}
# 5 0.5422 {'wins': 61, 'seen': 111}
# 6 0.5602 {'wins': 107, 'seen': 183}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 o _ _ _ _ _ _
# 2 x _ _ _ _ _ o
# 1 o x _ _ _ _ x
#   A B C D E F G
#
# 0 0.6811 {'wins': 19, 'seen': 29}
# 1 0.6396 {'wins': 33, 'seen': 51}
# 2 0.6667 {'wins': 23, 'seen': 35}
# 3 0.6172 {'wins': 15, 'seen': 24}
# 4 0.4782 {'wins': 21, 'seen': 37}
# 5 0.6343 {'wins': 30, 'seen': 45}
# 6 0.6372 {'wins': 21, 'seen': 33}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 o _ _ _ _ _ _
# 3 o _ _ _ _ _ _
# 2 x _ _ _ _ _ o
# 1 o x _ _ _ _ x
#   A B C D E F G
#
# 0 0.7428 {'wins': 15, 'seen': 20}
# 1 0.7546 {'wins': 19, 'seen': 25}
# 2 0.7316 {'wins': 16, 'seen': 22}
# 3 0.6995 {'wins': 15, 'seen': 21}
# 4 0.6974 {'wins': 16, 'seen': 22}
# 5 0.7393 {'wins': 16, 'seen': 22}
# 6 0.673 {'wins': 15, 'seen': 22}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 o _ _ _ _ _ _
# 3 o _ _ _ _ _ _
# 2 x x _ _ _ _ o
# 1 o x _ _ _ _ x
#   A B C D E F G
#
# 0 0.7016 {'wins': 15, 'seen': 21}
# 1 0.7335 {'wins': 15, 'seen': 21}
# 2 0.7032 {'wins': 15, 'seen': 21}
# 3 0.7653 {'wins': 15, 'seen': 20}
# 4 0.7229 {'wins': 15, 'seen': 21}
# 5 0.7584 {'wins': 17, 'seen': 22}
# 6 0.7519 {'wins': 15, 'seen': 20}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 o _ _ _ _ _ _
# 3 o _ _ _ _ _ _
# 2 x x _ _ _ _ o
# 1 o x _ o _ _ x
#   A B C D E F G
#
# 0 0.7212 {'wins': 15, 'seen': 20}
# 1 0.7238 {'wins': 15, 'seen': 20}
# 2 0.7655 {'wins': 15, 'seen': 20}
# 3 0.77 {'wins': 15, 'seen': 20}
# 4 0.7638 {'wins': 15, 'seen': 20}
# 5 0.7458 {'wins': 15, 'seen': 20}
# 6 0.7773 {'wins': 15, 'seen': 20}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 o _ _ _ _ _ _
# 3 o _ _ _ _ _ x
# 2 x x _ _ _ _ o
# 1 o x _ o _ _ x
#   A B C D E F G
#
# 0 0.7302 {'wins': 15, 'seen': 20}
# 1 0.7397 {'wins': 15, 'seen': 20}
# 2 0.7498 {'wins': 15, 'seen': 20}
# 3 0.7587 {'wins': 15, 'seen': 20}
# 4 0.7636 {'wins': 15, 'seen': 20}
# 5 0.8023 {'wins': 16, 'seen': 21}
# 6 0.7576 {'wins': 15, 'seen': 20}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 o _ _ _ _ _ _
# 3 o _ _ _ _ _ x
# 2 x x _ _ _ _ o
# 1 o x _ o _ o x
#   A B C D E F G
#
# 0 0.7469 {'wins': 15, 'seen': 20}
# 1 0.7181 {'wins': 15, 'seen': 21}
# 2 0.7364 {'wins': 15, 'seen': 21}
# 3 0.7201 {'wins': 15, 'seen': 20}
# 4 0.7067 {'wins': 15, 'seen': 20}
# 5 0.7122 {'wins': 15, 'seen': 20}
# 6 0.7359 {'wins': 15, 'seen': 20}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 x _ _ _ _ _ _
# 4 o _ _ _ _ _ _
# 3 o _ _ _ _ _ x
# 2 x x _ _ _ _ o
# 1 o x _ o _ o x
#   A B C D E F G
#
# 0 0.7669 {'wins': 15, 'seen': 20}
# 1 0.759 {'wins': 15, 'seen': 20}
# 2 0.7518 {'wins': 15, 'seen': 20}
# 3 0.752 {'wins': 15, 'seen': 20}
# 4 0.7766 {'wins': 15, 'seen': 20}
# 5 0.7354 {'wins': 15, 'seen': 20}
# 6 0.738 {'wins': 15, 'seen': 20}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 x _ _ _ _ _ _
# 4 o _ _ _ _ _ _
# 3 o _ _ _ _ _ x
# 2 x x _ _ _ _ o
# 1 o x _ o o o x
#   A B C D E F G
#
# 0 0.7406 {'wins': 15, 'seen': 20}
# 1 0.742 {'wins': 15, 'seen': 20}
# 2 0.7625 {'wins': 15, 'seen': 20}
# 3 0.7507 {'wins': 15, 'seen': 20}
# 4 0.7473 {'wins': 15, 'seen': 20}
# 5 0.756 {'wins': 15, 'seen': 20}
# 6 0.756 {'wins': 15, 'seen': 20}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 x _ _ _ _ _ _
# 4 o _ _ _ _ _ _
# 3 o _ _ _ _ _ x
# 2 x x _ _ _ _ o
# 1 o x x o o o x
#   A B C D E F G
#
# 0 0.7631 {'wins': 15, 'seen': 20}
# 1 0.7633 {'wins': 15, 'seen': 20}
# 2 0.7856 {'wins': 15, 'seen': 20}
# 3 0.7427 {'wins': 15, 'seen': 20}
# 4 0.7095 {'wins': 15, 'seen': 20}
# 5 0.7512 {'wins': 15, 'seen': 20}
# 6 0.7373 {'wins': 15, 'seen': 20}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 x _ _ _ _ _ _
# 4 o _ _ _ _ _ _
# 3 o _ _ _ _ _ x
# 2 x x o _ _ _ o
# 1 o x x o o o x
#   A B C D E F G
#
# 0 0.7675 {'wins': 15, 'seen': 20}
# 1 0.7629 {'wins': 15, 'seen': 20}
# 2 0.7487 {'wins': 15, 'seen': 20}
# 3 0.7274 {'wins': 15, 'seen': 20}
# 4 0.746 {'wins': 15, 'seen': 20}
# 5 0.7681 {'wins': 15, 'seen': 20}
# 6 0.7171 {'wins': 15, 'seen': 20}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 x _ _ _ _ _ _
# 4 o _ _ _ _ _ _
# 3 o _ _ _ _ _ x
# 2 x x o _ _ x o
# 1 o x x o o o x
#   A B C D E F G
#
# 0 0.7672 {'wins': 15, 'seen': 20}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 x _ _ _ _ _ _
# 4 o _ _ _ _ _ _
# 3 o o _ _ _ _ x
# 2 x x o _ _ x o
# 1 o x x o o o x
#   A B C D E F G
#
# PLAYER WON \-
# 0 0.4232 {'wins': 8272, 'seen': 18547}
# 1 0.4022 {'wins': 1547, 'seen': 3745}
# 2 0.3434 {'wins': 1174, 'seen': 3075}
# 3 0.2422 {'wins': 755, 'seen': 3005}
# 4 0.3819 {'wins': 1235, 'seen': 3130}
# 5 0.4112 {'wins': 1448, 'seen': 3542}
# 6 0.4337 {'wins': 7082, 'seen': 16201}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 _ _ _ _ _ _ _
# 1 _ _ _ _ _ _ o
#   A B C D E F G
#
# 0 0.6103 {'wins': 5425, 'seen': 8949}
# 1 0.4862 {'wins': 482, 'seen': 924}
# 2 0.5217 {'wins': 446, 'seen': 908}
# 3 0.3633 {'wins': 316, 'seen': 872}
# 4 0.4254 {'wins': 409, 'seen': 902}
# 5 0.5101 {'wins': 513, 'seen': 979}
# 6 0.5787 {'wins': 1628, 'seen': 2787}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 _ _ _ _ _ _ _
# 1 x _ _ _ _ _ o
#   A B C D E F G
#
# 0 0.4227 {'wins': 1748, 'seen': 4070}
# 1 0.3688 {'wins': 348, 'seen': 911}
# 2 0.3371 {'wins': 146, 'seen': 425}
# 3 0.2342 {'wins': 92, 'seen': 402}
# 4 0.3682 {'wins': 163, 'seen': 455}
# 5 0.397 {'wins': 610, 'seen': 1567}
# 6 0.3516 {'wins': 660, 'seen': 1623}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 o _ _ _ _ _ _
# 1 x _ _ _ _ _ o
#   A B C D E F G
#
# 0 0.5792 {'wins': 961, 'seen': 1625}
# 1 0.556 {'wins': 101, 'seen': 185}
# 2 0.5333 {'wins': 74, 'seen': 140}
# 3 0.3592 {'wins': 48, 'seen': 130}
# 4 0.5539 {'wins': 94, 'seen': 177}
# 5 0.5938 {'wins': 231, 'seen': 410}
# 6 0.6039 {'wins': 913, 'seen': 1523}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 o _ _ _ _ _ x
# 1 x _ _ _ _ _ o
#   A B C D E F G
#
# 0 0.3762 {'wins': 38, 'seen': 99}
# 1 0.4121 {'wins': 101, 'seen': 248}
# 2 0.3335 {'wins': 28, 'seen': 77}
# 3 0.3444 {'wins': 30, 'seen': 82}
# 4 0.4345 {'wins': 78, 'seen': 190}
# 5 0.4178 {'wins': 114, 'seen': 278}
# 6 0.4398 {'wins': 417, 'seen': 938}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ o
# 2 o _ _ _ _ _ x
# 1 x _ _ _ _ _ o
#   A B C D E F G
#
# 0 0.6089 {'wins': 243, 'seen': 398}
# 1 0.5263 {'wins': 54, 'seen': 96}
# 2 0.566 {'wins': 29, 'seen': 52}
# 3 0.5567 {'wins': 25, 'seen': 45}
# 4 0.5159 {'wins': 33, 'seen': 63}
# 5 0.5125 {'wins': 36, 'seen': 66}
# 6 0.6024 {'wins': 201, 'seen': 338}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 x _ _ _ _ _ o
# 2 o _ _ _ _ _ x
# 1 x _ _ _ _ _ o
#   A B C D E F G
#
# 0 0.4669 {'wins': 43, 'seen': 89}
# 1 0.4404 {'wins': 26, 'seen': 57}
# 2 0.4825 {'wins': 32, 'seen': 68}
# 3 0.5073 {'wins': 40, 'seen': 84}
# 4 0.467 {'wins': 42, 'seen': 88}
# 5 0.4933 {'wins': 54, 'seen': 107}
# 6 0.4797 {'wins': 40, 'seen': 84}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 x _ _ _ _ _ o
# 2 o _ _ _ _ _ x
# 1 x _ _ o _ _ o
#   A B C D E F G
#
# 0 0.701 {'wins': 27, 'seen': 38}
# 1 0.7557 {'wins': 25, 'seen': 34}
# 2 0.6951 {'wins': 17, 'seen': 24}
# 3 0.6596 {'wins': 15, 'seen': 22}
# 4 0.6755 {'wins': 23, 'seen': 34}
# 5 0.7124 {'wins': 22, 'seen': 31}
# 6 0.7292 {'wins': 17, 'seen': 24}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 x _ _ _ _ _ o
# 2 o _ _ _ _ _ x
# 1 x x _ o _ _ o
#   A B C D E F G
#
# 0 0.6758 {'wins': 15, 'seen': 22}
# 1 0.7293 {'wins': 17, 'seen': 24}
# 2 0.6789 {'wins': 17, 'seen': 25}
# 3 0.6743 {'wins': 16, 'seen': 23}
# 4 0.6761 {'wins': 15, 'seen': 22}
# 5 0.6548 {'wins': 16, 'seen': 24}
# 6 0.6705 {'wins': 15, 'seen': 22}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 x _ _ _ _ _ o
# 2 o o _ _ _ _ x
# 1 x x _ o _ _ o
#   A B C D E F G
#
# 0 0.7639 {'wins': 16, 'seen': 22}
# 1 0.75 {'wins': 15, 'seen': 20}
# 2 0.7263 {'wins': 16, 'seen': 22}
# 3 0.7793 {'wins': 16, 'seen': 21}
# 4 0.7409 {'wins': 16, 'seen': 21}
# 5 0.7475 {'wins': 15, 'seen': 20}
# 6 0.7409 {'wins': 15, 'seen': 20}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 x _ _ _ _ _ o
# 2 o o _ x _ _ x
# 1 x x _ o _ _ o
#   A B C D E F G
#
# 0 0.7568 {'wins': 15, 'seen': 20}
# 1 0.7551 {'wins': 15, 'seen': 20}
# 2 0.7326 {'wins': 15, 'seen': 21}
# 3 0.7536 {'wins': 15, 'seen': 20}
# 4 0.7478 {'wins': 15, 'seen': 20}
# 5 0.7018 {'wins': 15, 'seen': 21}
# 6 0.7672 {'wins': 15, 'seen': 20}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ o
# 3 x _ _ _ _ _ o
# 2 o o _ x _ _ x
# 1 x x _ o _ _ o
#   A B C D E F G
#
# 0 0.7379 {'wins': 15, 'seen': 20}
# 1 0.7601 {'wins': 15, 'seen': 20}
# 2 0.7375 {'wins': 15, 'seen': 20}
# 3 0.7473 {'wins': 15, 'seen': 20}
# 4 0.7478 {'wins': 15, 'seen': 20}
# 5 0.7517 {'wins': 15, 'seen': 20}
# 6 0.7938 {'wins': 15, 'seen': 20}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ x
# 4 _ _ _ _ _ _ o
# 3 x _ _ _ _ _ o
# 2 o o _ x _ _ x
# 1 x x _ o _ _ o
#   A B C D E F G
#
# 0 0.7498 {'wins': 15, 'seen': 20}
# 1 0.7619 {'wins': 15, 'seen': 20}
# 2 0.7283 {'wins': 15, 'seen': 20}
# 3 0.7312 {'wins': 15, 'seen': 20}
# 4 0.7244 {'wins': 15, 'seen': 20}
# 5 0.7326 {'wins': 15, 'seen': 20}
# 6 0.7566 {'wins': 15, 'seen': 20}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ x
# 4 _ _ _ _ _ _ o
# 3 x o _ _ _ _ o
# 2 o o _ x _ _ x
# 1 x x _ o _ _ o
#   A B C D E F G
#
# 0 0.7587 {'wins': 15, 'seen': 20}
# 1 0.7358 {'wins': 15, 'seen': 20}
# 2 0.7399 {'wins': 15, 'seen': 20}
# 3 0.7544 {'wins': 15, 'seen': 20}
# 4 0.7162 {'wins': 15, 'seen': 20}
# 5 0.7321 {'wins': 15, 'seen': 20}
# 6 0.7454 {'wins': 15, 'seen': 20}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ x
# 4 x _ _ _ _ _ o
# 3 x o _ _ _ _ o
# 2 o o _ x _ _ x
# 1 x x _ o _ _ o
#   A B C D E F G
#
# 0 0.7212 {'wins': 15, 'seen': 20}
# 1 0.7389 {'wins': 15, 'seen': 20}
# 2 0.7365 {'wins': 15, 'seen': 20}
# 3 0.7361 {'wins': 15, 'seen': 20}
# 4 0.7549 {'wins': 15, 'seen': 20}
# 5 0.7568 {'wins': 15, 'seen': 20}
# 6 0.7765 {'wins': 15, 'seen': 20}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ o
# 5 _ _ _ _ _ _ x
# 4 x _ _ _ _ _ o
# 3 x o _ _ _ _ o
# 2 o o _ x _ _ x
# 1 x x _ o _ _ o
#   A B C D E F G
#
# 0 0.7585 {'wins': 15, 'seen': 20}
# 1 0.7617 {'wins': 15, 'seen': 20}
# 2 0.7407 {'wins': 15, 'seen': 20}
# 3 0.7677 {'wins': 15, 'seen': 20}
# 4 0.7339 {'wins': 15, 'seen': 20}
# 5 0.7252 {'wins': 15, 'seen': 20}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ o
# 5 _ _ _ _ _ _ x
# 4 x _ _ _ _ _ o
# 3 x o _ x _ _ o
# 2 o o _ x _ _ x
# 1 x x _ o _ _ o
#   A B C D E F G
#
# 0 0.7668 {'wins': 15, 'seen': 20}
# 1 0.7708 {'wins': 15, 'seen': 20}
# 2 0.7232 {'wins': 15, 'seen': 20}
# 3 0.7264 {'wins': 15, 'seen': 20}
# 4 0.7184 {'wins': 15, 'seen': 20}
# 5 0.7615 {'wins': 15, 'seen': 20}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ o
# 5 _ _ _ _ _ _ x
# 4 x o _ _ _ _ o
# 3 x o _ x _ _ o
# 2 o o _ x _ _ x
# 1 x x _ o _ _ o
#   A B C D E F G
#
# 0 0.734 {'wins': 15, 'seen': 20}
# 1 0.7761 {'wins': 15, 'seen': 20}
# 2 0.7365 {'wins': 15, 'seen': 20}
# 3 0.7248 {'wins': 15, 'seen': 20}
# 4 0.7306 {'wins': 15, 'seen': 20}
# 5 0.7305 {'wins': 15, 'seen': 20}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ o
# 5 _ x _ _ _ _ x
# 4 x o _ _ _ _ o
# 3 x o _ x _ _ o
# 2 o o _ x _ _ x
# 1 x x _ o _ _ o
#   A B C D E F G
#
# 0 0.7569 {'wins': 15, 'seen': 20}
# 1 0.7435 {'wins': 15, 'seen': 20}
# 2 0.7689 {'wins': 15, 'seen': 20}
# 3 0.7679 {'wins': 15, 'seen': 20}
# 4 0.7684 {'wins': 15, 'seen': 20}
# 5 0.7148 {'wins': 15, 'seen': 20}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ o
# 5 _ x _ _ _ _ x
# 4 x o _ _ _ _ o
# 3 x o _ x _ _ o
# 2 o o _ x _ _ x
# 1 x x o o _ _ o
#   A B C D E F G
#
# 0 0.7475 {'wins': 15, 'seen': 20}
# 1 0.758 {'wins': 15, 'seen': 20}
# 2 0.7778 {'wins': 15, 'seen': 20}
# 3 0.7371 {'wins': 15, 'seen': 20}
# 4 0.7303 {'wins': 15, 'seen': 20}
# 5 0.7537 {'wins': 15, 'seen': 20}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ o
# 5 _ x _ _ _ _ x
# 4 x o _ _ _ _ o
# 3 x o _ x _ _ o
# 2 o o x x _ _ x
# 1 x x o o _ _ o
#   A B C D E F G
#
# 0 0.7289 {'wins': 15, 'seen': 20}
# 1 0.7557 {'wins': 15, 'seen': 20}
# 2 0.7263 {'wins': 15, 'seen': 20}
# 3 0.7395 {'wins': 15, 'seen': 20}
# 4 0.7458 {'wins': 15, 'seen': 20}
# 5 0.7442 {'wins': 15, 'seen': 20}
# WHITE TO MOVE
# 6 _ o _ _ _ _ o
# 5 _ x _ _ _ _ x
# 4 x o _ _ _ _ o
# 3 x o _ x _ _ o
# 2 o o x x _ _ x
# 1 x x o o _ _ o
#   A B C D E F G
#
# 0 0.7479 {'wins': 15, 'seen': 20}
# 2 0.7236 {'wins': 15, 'seen': 20}
# 3 0.7594 {'wins': 15, 'seen': 20}
# 4 0.7497 {'wins': 15, 'seen': 20}
# 5 0.745 {'wins': 15, 'seen': 20}
# BLACK TO MOVE
# 6 _ o _ _ _ _ o
# 5 _ x _ _ _ _ x
# 4 x o _ x _ _ o
# 3 x o _ x _ _ o
# 2 o o x x _ _ x
# 1 x x o o _ _ o
#   A B C D E F G
#
# 0 0.7701 {'wins': 15, 'seen': 20}
# 2 0.7482 {'wins': 15, 'seen': 20}
# 3 0.765 {'wins': 15, 'seen': 20}
# 4 0.7371 {'wins': 15, 'seen': 20}
# 5 0.7537 {'wins': 15, 'seen': 20}
# WHITE TO MOVE
# 6 _ o _ _ _ _ o
# 5 o x _ _ _ _ x
# 4 x o _ x _ _ o
# 3 x o _ x _ _ o
# 2 o o x x _ _ x
# 1 x x o o _ _ o
#   A B C D E F G
#
# 0 0.7622 {'wins': 15, 'seen': 20}
# 2 0.7595 {'wins': 15, 'seen': 20}
# BLACK TO MOVE
# 6 _ o _ _ _ _ o
# 5 o x _ x _ _ x
# 4 x o _ x _ _ o
# 3 x o _ x _ _ o
# 2 o o x x _ _ x
# 1 x x o o _ _ o
#   A B C D E F G
#
# PLAYER WON |
# 0 0.4729 {'wins': 8272, 'seen': 18547}
# 1 0.3984 {'wins': 1547, 'seen': 3745}
# 2 0.3802 {'wins': 1174, 'seen': 3075}
# 3 0.268 {'wins': 755, 'seen': 3005}
# 4 0.3863 {'wins': 1235, 'seen': 3130}
# 5 0.4129 {'wins': 1448, 'seen': 3542}
# 6 0.4383 {'wins': 7083, 'seen': 16202}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 _ _ _ _ _ _ _
# 1 o _ _ _ _ _ _
#   A B C D E F G
#
# 0 0.536 {'wins': 1560, 'seen': 2783}
# 1 0.4943 {'wins': 487, 'seen': 972}
# 2 0.4193 {'wins': 378, 'seen': 836}
# 3 0.3504 {'wins': 323, 'seen': 877}
# 4 0.492 {'wins': 678, 'seen': 1285}
# 5 0.5451 {'wins': 550, 'seen': 1035}
# 6 0.5769 {'wins': 6399, 'seen': 10879}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 _ _ _ _ _ _ _
# 1 o _ _ _ _ _ x
#   A B C D E F G
#
# 0 0.447 {'wins': 1063, 'seen': 2486}
# 1 0.3955 {'wins': 298, 'seen': 754}
# 2 0.353 {'wins': 148, 'seen': 421}
# 3 0.2308 {'wins': 123, 'seen': 508}
# 4 0.3898 {'wins': 207, 'seen': 539}
# 5 0.4255 {'wins': 668, 'seen': 1639}
# 6 0.4721 {'wins': 2278, 'seen': 5151}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 _ _ _ _ _ _ o
# 1 o _ _ _ _ _ x
#   A B C D E F G
#
# 0 0.6158 {'wins': 1174, 'seen': 1983}
# 1 0.5402 {'wins': 117, 'seen': 221}
# 2 0.5411 {'wins': 117, 'seen': 232}
# 3 0.3659 {'wins': 62, 'seen': 177}
# 4 0.5079 {'wins': 79, 'seen': 170}
# 5 0.5189 {'wins': 78, 'seen': 153}
# 6 0.5898 {'wins': 1346, 'seen': 2335}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 x _ _ _ _ _ o
# 1 o _ _ _ _ _ x
#   A B C D E F G
#
# 0 0.4264 {'wins': 472, 'seen': 1050}
# 1 0.429 {'wins': 168, 'seen': 402}
# 2 0.3792 {'wins': 43, 'seen': 106}
# 3 0.3021 {'wins': 26, 'seen': 83}
# 4 0.3972 {'wins': 62, 'seen': 154}
# 5 0.3931 {'wins': 140, 'seen': 346}
# 6 0.4305 {'wins': 120, 'seen': 276}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ o
# 2 x _ _ _ _ _ o
# 1 o _ _ _ _ _ x
#   A B C D E F G
#
# 0 0.6892 {'wins': 81, 'seen': 120}
# 1 0.6434 {'wins': 55, 'seen': 86}
# 2 0.5822 {'wins': 39, 'seen': 65}
# 3 0.5576 {'wins': 18, 'seen': 31}
# 4 0.6081 {'wins': 30, 'seen': 48}
# 5 0.6121 {'wins': 30, 'seen': 48}
# 6 0.6429 {'wins': 22, 'seen': 35}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 x _ _ _ _ _ o
# 2 x _ _ _ _ _ o
# 1 o _ _ _ _ _ x
#   A B C D E F G
#
# 0 0.5673 {'wins': 22, 'seen': 38}
# 1 0.5862 {'wins': 32, 'seen': 55}
# 2 0.5323 {'wins': 18, 'seen': 33}
# 3 0.6008 {'wins': 16, 'seen': 28}
# 4 0.5987 {'wins': 18, 'seen': 32}
# 5 0.5727 {'wins': 28, 'seen': 49}
# 6 0.5401 {'wins': 16, 'seen': 30}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 x _ _ _ _ _ o
# 2 x _ _ _ _ _ o
# 1 o _ _ o _ _ x
#   A B C D E F G
#
# 0 0.7343 {'wins': 15, 'seen': 21}
# 1 0.7736 {'wins': 22, 'seen': 28}
# 2 0.7445 {'wins': 16, 'seen': 22}
# 3 0.7271 {'wins': 15, 'seen': 20}
# 4 0.7882 {'wins': 16, 'seen': 21}
# 5 0.7673 {'wins': 16, 'seen': 21}
# 6 0.7441 {'wins': 16, 'seen': 21}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 x _ _ _ _ _ o
# 2 x _ _ _ _ _ o
# 1 o _ _ o x _ x
#   A B C D E F G
#
# 0 0.7418 {'wins': 15, 'seen': 20}
# 1 0.714 {'wins': 15, 'seen': 21}
# 2 0.7687 {'wins': 15, 'seen': 21}
# 3 0.7144 {'wins': 15, 'seen': 20}
# 4 0.7199 {'wins': 15, 'seen': 20}
# 5 0.7665 {'wins': 15, 'seen': 20}
# 6 0.7599 {'wins': 15, 'seen': 20}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 x _ _ _ _ _ o
# 2 x _ _ _ _ _ o
# 1 o _ o o x _ x
#   A B C D E F G
#
# 0 0.7625 {'wins': 15, 'seen': 20}
# 1 0.7747 {'wins': 16, 'seen': 21}
# 2 0.7522 {'wins': 15, 'seen': 20}
# 3 0.7736 {'wins': 15, 'seen': 20}
# 4 0.7698 {'wins': 16, 'seen': 21}
# 5 0.7776 {'wins': 15, 'seen': 20}
# 6 0.7317 {'wins': 15, 'seen': 20}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 x _ _ _ _ _ o
# 2 x _ _ _ _ _ o
# 1 o _ o o x x x
#   A B C D E F G
#
# 0 0.7814 {'wins': 15, 'seen': 20}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 x _ _ _ _ _ o
# 2 x _ _ _ _ _ o
# 1 o o o o x x x
#   A B C D E F G
#
# PLAYER WON -

# %%
len(table)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-bfb8bb9a6394> in <module>()
# ----> 1 len(table)
#
# TypeError: object of type 'bool' has no len()

# %%
table = ai.table

# %%
# b.print_board(list((556206917161, 50538708)), 0)

# %%
seen_tot = 0
wins_tot = 0
for v in table.values():
    seen_tot += v['seen'] - 20
    wins_tot += v['wins'] - 10

#     print(v,k)

print(seen_tot, wins_tot, float(wins_tot) / seen_tot)
avg_seen = seen_tot / len(table)

print(avg_seen)

# %%
ai.Run(1,0,True)

# %%
x = []
for u in range(1000):
    x.append( np.random.randint(0,6))

# %%
max(x)

# %%
min(x)

# %%
\
