# %%
from board import Board
import random
import pickle
from Table_ai import Table_ai
import numpy as np

# %%
ai = Table_ai()
b = Board()

# %%
ai.table
# Out:
# {}

# %%
ai.Run(1000,.4, False)
# ai.Run(1, 0, True)
ai.Run(10000, .2)
ai.Run(100000, .1)
# print("\n\nAfter 0.1 \n\n")
# print("----------------------------")
# print("----------------------------")
# print("----------------------------")

for i in range(1, 10):
# ai.Run(1, 0, True)
    ai.Run(1000000, .01)
# ai.Run(100000, 0.1)
# ai.Run(1000, 0.5)
#ai.Run(1000000, 0.05)
    print(i)
print("\n\nFINAL\n\n")
print("----------------------------")
print("----------------------------")
print("----------------------------")

table = ai.Run(1, 0, True)
# Out:
# 1000 0.4 False
# 10000 0.2 False
# 100000 0.1 False
# 1000000 0.01 False
# 1
# 1000000 0.01 False
# 2
# 1000000 0.01 False
# 3
# 1000000 0.01 False
# 4
# 1000000 0.01 False
# 5
# 1000000 0.01 False
# 6
# 1000000 0.01 False
# 7
# 1000000 0.01 False
# 8
# 1000000 0.01 False
# 9
#
#
# FINAL
#
#
# ----------------------------
# ----------------------------
# ----------------------------
# 1 0 True
# 0 0.4556 {'wins': 242, 'seen': 530}
# 1 0.5044 {'wins': 281, 'seen': 558}
# 2 0.5652 {'wins': 307, 'seen': 544}
# 3 0.6434 {'wins': 24972, 'seen': 38830}
# 4 0.531 {'wins': 284, 'seen': 535}
# 5 0.5027 {'wins': 257, 'seen': 510}
# 6 0.4373 {'wins': 248, 'seen': 568}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 _ _ _ _ _ _ _
# 1 _ _ _ o _ _ _
#   A B C D E F G
#
# 0 0.2803 {'wins': 141, 'seen': 504}
# 1 0.3083 {'wins': 128, 'seen': 415}
# 2 0.3379 {'wins': 591, 'seen': 1754}
# 3 0.3115 {'wins': 153, 'seen': 492}
# 4 0.3625 {'wins': 12654, 'seen': 34910}
# 5 0.3196 {'wins': 142, 'seen': 445}
# 6 0.2916 {'wins': 125, 'seen': 430}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 _ _ _ _ _ _ _
# 1 _ _ _ o x _ _
#   A B C D E F G
#
# 0 0.6059 {'wins': 289, 'seen': 477}
# 1 0.6033 {'wins': 860, 'seen': 1425}
# 2 0.5591 {'wins': 285, 'seen': 510}
# 3 0.6305 {'wins': 6905, 'seen': 10956}
# 4 0.6498 {'wins': 13335, 'seen': 20553}
# 5 0.627 {'wins': 499, 'seen': 796}
# 6 0.5222 {'wins': 182, 'seen': 348}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 _ _ _ _ o _ _
# 1 _ _ _ o x _ _
#   A B C D E F G
#
# 0 0.3439 {'wins': 182, 'seen': 532}
# 1 0.3467 {'wins': 1328, 'seen': 3821}
# 2 0.2951 {'wins': 49, 'seen': 166}
# 3 0.3572 {'wins': 5460, 'seen': 15273}
# 4 0.3459 {'wins': 199, 'seen': 575}
# 5 0.2488 {'wins': 39, 'seen': 157}
# 6 0.2475 {'wins': 37, 'seen': 149}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ _ _ _
# 2 _ _ _ x o _ _
# 1 _ _ _ o x _ _
#   A B C D E F G
#
# 0 0.5716 {'wins': 48, 'seen': 84}
# 1 0.6054 {'wins': 208, 'seen': 343}
# 2 0.5689 {'wins': 70, 'seen': 123}
# 3 0.6038 {'wins': 49, 'seen': 81}
# 4 0.6444 {'wins': 9441, 'seen': 14630}
# 5 0.5672 {'wins': 45, 'seen': 79}
# 6 0.5692 {'wins': 58, 'seen': 102}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ _ _ _
# 3 _ _ _ _ o _ _
# 2 _ _ _ x o _ _
# 1 _ _ _ o x _ _
#   A B C D E F G
#
# 0 0.3365 {'wins': 32, 'seen': 95}
# 1 0.2824 {'wins': 22, 'seen': 78}
# 2 0.1911 {'wins': 19, 'seen': 99}
# 3 0.3347 {'wins': 45, 'seen': 134}
# 4 0.3601 {'wins': 5106, 'seen': 14198}
# 5 0.2504 {'wins': 16, 'seen': 64}
# 6 0.2856 {'wins': 25, 'seen': 88}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ x _ _
# 3 _ _ _ _ o _ _
# 2 _ _ _ x o _ _
# 1 _ _ _ o x _ _
#   A B C D E F G
#
# 0 0.5417 {'wins': 39, 'seen': 72}
# 1 0.5742 {'wins': 182, 'seen': 317}
# 2 0.5979 {'wins': 3123, 'seen': 5216}
# 3 0.6745 {'wins': 5661, 'seen': 8420}
# 4 0.5161 {'wins': 33, 'seen': 64}
# 5 0.5075 {'wins': 33, 'seen': 65}
# 6 0.5944 {'wins': 97, 'seen': 164}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ _ x _ _
# 3 _ _ _ o o _ _
# 2 _ _ _ x o _ _
# 1 _ _ _ o x _ _
#   A B C D E F G
#
# 0 0.327 {'wins': 19, 'seen': 58}
# 1 0.3303 {'wins': 350, 'seen': 1064}
# 2 0.3146 {'wins': 15, 'seen': 48}
# 3 0.3329 {'wins': 2383, 'seen': 7156}
# 4 0.2794 {'wins': 16, 'seen': 57}
# 5 0.3218 {'wins': 36, 'seen': 112}
# 6 0.3104 {'wins': 18, 'seen': 58}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ x x _ _
# 3 _ _ _ o o _ _
# 2 _ _ _ x o _ _
# 1 _ _ _ o x _ _
#   A B C D E F G
#
# 0 0.549 {'wins': 17, 'seen': 31}
# 1 0.5431 {'wins': 25, 'seen': 46}
# 2 0.6717 {'wins': 4660, 'seen': 6938}
# 3 0.5562 {'wins': 20, 'seen': 36}
# 4 0.5592 {'wins': 90, 'seen': 161}
# 5 0.5583 {'wins': 19, 'seen': 34}
# 6 0.6001 {'wins': 18, 'seen': 30}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ x x _ _
# 3 _ _ _ o o _ _
# 2 _ _ _ x o _ _
# 1 _ _ o o x _ _
#   A B C D E F G
#
# 0 0.3386 {'wins': 1034, 'seen': 3040}
# 1 0.3442 {'wins': 1683, 'seen': 4900}
# 2 0.3187 {'wins': 21, 'seen': 66}
# 3 0.338 {'wins': 23, 'seen': 68}
# 4 0.334 {'wins': 30, 'seen': 90}
# 5 0.3337 {'wins': 19, 'seen': 57}
# 6 0.3373 {'wins': 33, 'seen': 98}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ x x _ _
# 3 _ _ _ o o _ _
# 2 _ _ _ x o _ _
# 1 _ x o o x _ _
#   A B C D E F G
#
# 0 0.4853 {'wins': 15, 'seen': 31}
# 1 0.664 {'wins': 3177, 'seen': 4796}
# 2 0.5582 {'wins': 19, 'seen': 34}
# 3 0.4013 {'wins': 16, 'seen': 40}
# 4 0.5256 {'wins': 21, 'seen': 40}
# 5 0.5142 {'wins': 18, 'seen': 35}
# 6 0.5932 {'wins': 29, 'seen': 49}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ x x _ _
# 3 _ _ _ o o _ _
# 2 _ o _ x o _ _
# 1 _ x o o x _ _
#   A B C D E F G
#
# 0 0.3425 {'wins': 644, 'seen': 1879}
# 1 0.3423 {'wins': 224, 'seen': 656}
# 2 0.339 {'wins': 21, 'seen': 62}
# 3 0.3396 {'wins': 18, 'seen': 53}
# 4 0.3405 {'wins': 38, 'seen': 112}
# 5 0.349 {'wins': 714, 'seen': 2050}
# 6 0.3401 {'wins': 36, 'seen': 106}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ _ _ _ _
# 4 _ _ _ x x _ _
# 3 _ _ _ o o _ _
# 2 _ o _ x o _ _
# 1 _ x o o x x _
#   A B C D E F G
#
# 0 0.5555 {'wins': 40, 'seen': 72}
# 1 0.6137 {'wins': 16, 'seen': 26}
# 2 0.5657 {'wins': 17, 'seen': 30}
# 3 0.6596 {'wins': 1283, 'seen': 1940}
# 4 0.5504 {'wins': 22, 'seen': 40}
# 5 0.5429 {'wins': 19, 'seen': 35}
# 6 0.5352 {'wins': 15, 'seen': 28}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ o _ _ _
# 4 _ _ _ x x _ _
# 3 _ _ _ o o _ _
# 2 _ o _ x o _ _
# 1 _ x o o x x _
#   A B C D E F G
#
# 0 0.3459 {'wins': 18, 'seen': 52}
# 1 0.3469 {'wins': 18, 'seen': 52}
# 2 0.3329 {'wins': 20, 'seen': 60}
# 3 0.3533 {'wins': 507, 'seen': 1439}
# 4 0.3532 {'wins': 74, 'seen': 211}
# 5 0.3432 {'wins': 13, 'seen': 38}
# 6 0.3966 {'wins': 83, 'seen': 210}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ o _ _ _
# 4 _ _ _ x x _ _
# 3 _ _ _ o o _ _
# 2 _ o _ x o _ _
# 1 _ x o o x x x
#   A B C D E F G
#
# 0 0.5986 {'wins': 12, 'seen': 20}
# 1 0.5994 {'wins': 15, 'seen': 25}
# 2 0.6014 {'wins': 21, 'seen': 35}
# 3 0.5908 {'wins': 13, 'seen': 22}
# 4 0.547 {'wins': 12, 'seen': 22}
# 5 0.6318 {'wins': 119, 'seen': 188}
# 6 0.6007 {'wins': 12, 'seen': 20}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ o _ _ _
# 4 _ _ _ x x _ _
# 3 _ _ _ o o _ _
# 2 _ o _ x o o _
# 1 _ x o o x x x
#   A B C D E F G
#
# 0 0.461 {'wins': 18, 'seen': 39}
# 1 0.4612 {'wins': 12, 'seen': 26}
# 2 0.4523 {'wins': 14, 'seen': 31}
# 3 0.4616 {'wins': 12, 'seen': 26}
# 4 0.4638 {'wins': 19, 'seen': 41}
# 5 0.4861 {'wins': 55, 'seen': 113}
# 6 0.4538 {'wins': 15, 'seen': 33}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ o _ _ _
# 4 _ _ _ x x _ _
# 3 _ _ _ o o x _
# 2 _ o _ x o o _
# 1 _ x o o x x x
#   A B C D E F G
#
# 0 0.5413 {'wins': 13, 'seen': 24}
# 1 0.5537 {'wins': 20, 'seen': 36}
# 2 0.5511 {'wins': 16, 'seen': 29}
# 3 0.5587 {'wins': 14, 'seen': 25}
# 4 0.5462 {'wins': 12, 'seen': 22}
# 5 0.5527 {'wins': 26, 'seen': 47}
# 6 0.66 {'wins': 33, 'seen': 50}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ o _ _ _
# 4 _ _ _ x x _ _
# 3 _ _ _ o o x _
# 2 _ o _ x o o o
# 1 _ x o o x x x
#   A B C D E F G
#
# 0 0.5397 {'wins': 13, 'seen': 24}
# 1 0.5443 {'wins': 12, 'seen': 22}
# 2 0.5459 {'wins': 12, 'seen': 22}
# 3 0.5385 {'wins': 14, 'seen': 26}
# 4 0.5227 {'wins': 12, 'seen': 23}
# 5 0.5456 {'wins': 12, 'seen': 22}
# 6 0.5615 {'wins': 18, 'seen': 32}
# BLACK TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ o _ _ _
# 4 _ _ _ x x _ _
# 3 _ _ _ o o x x
# 2 _ o _ x o o o
# 1 _ x o o x x x
#   A B C D E F G
#
# 0 0.5907 {'wins': 13, 'seen': 22}
# 1 0.5986 {'wins': 12, 'seen': 20}
# 2 0.5708 {'wins': 12, 'seen': 21}
# 3 0.5717 {'wins': 12, 'seen': 21}
# 4 0.5909 {'wins': 13, 'seen': 22}
# 5 0.5839 {'wins': 14, 'seen': 24}
# 6 0.6366 {'wins': 14, 'seen': 22}
# WHITE TO MOVE
# 6 _ _ _ _ _ _ _
# 5 _ _ _ o _ _ _
# 4 _ _ _ x x _ o
# 3 _ _ _ o o x x
# 2 _ o _ x o o o
# 1 _ x o o x x x
#   A B C D E F G
#
# 0 0.5723 {'wins': 12, 'seen': 21}
# 1 0.601 {'wins': 12, 'seen': 20}
# 2 0.5728 {'wins': 12, 'seen': 21}
# 3 0.6017 {'wins': 12, 'seen': 20}
# 4 0.6003 {'wins': 12, 'seen': 20}
# 5 0.5998 {'wins': 12, 'seen': 20}
# 6 0.599 {'wins': 12, 'seen': 20}
# BLACK TO MOVE
# 6 _ _ _ x _ _ _
# 5 _ _ _ o _ _ _
# 4 _ _ _ x x _ o
# 3 _ _ _ o o x x
# 2 _ o _ x o o o
# 1 _ x o o x x x
#   A B C D E F G
#
# 0 0.6002 {'wins': 12, 'seen': 20}
# 1 0.6013 {'wins': 12, 'seen': 20}
# 2 0.5982 {'wins': 12, 'seen': 20}
# 4 0.6012 {'wins': 12, 'seen': 20}
# 5 0.5992 {'wins': 12, 'seen': 20}
# 6 0.5993 {'wins': 12, 'seen': 20}
# WHITE TO MOVE
# 6 _ _ _ x _ _ _
# 5 _ _ _ o _ _ _
# 4 _ _ _ x x _ o
# 3 _ o _ o o x x
# 2 _ o _ x o o o
# 1 _ x o o x x x
#   A B C D E F G
#
# 0 0.6003 {'wins': 12, 'seen': 20}
# 1 0.6003 {'wins': 12, 'seen': 20}
# 2 0.5996 {'wins': 12, 'seen': 20}
# 4 0.6012 {'wins': 12, 'seen': 20}
# 5 0.6016 {'wins': 12, 'seen': 20}
# 6 0.6001 {'wins': 12, 'seen': 20}
# BLACK TO MOVE
# 6 _ _ _ x _ _ _
# 5 _ _ _ o _ _ _
# 4 _ _ _ x x x o
# 3 _ o _ o o x x
# 2 _ o _ x o o o
# 1 _ x o o x x x
#   A B C D E F G
#
# 0 0.6007 {'wins': 12, 'seen': 20}
# 1 0.5973 {'wins': 12, 'seen': 20}
# 2 0.6011 {'wins': 12, 'seen': 20}
# 4 0.6001 {'wins': 12, 'seen': 20}
# 5 0.5986 {'wins': 12, 'seen': 20}
# 6 0.5998 {'wins': 12, 'seen': 20}
# WHITE TO MOVE
# 6 _ _ _ x _ _ _
# 5 _ _ _ o _ _ _
# 4 _ _ _ x x x o
# 3 _ o _ o o x x
# 2 _ o o x o o o
# 1 _ x o o x x x
#   A B C D E F G
#
# 0 0.5996 {'wins': 12, 'seen': 20}
# 1 0.6009 {'wins': 12, 'seen': 20}
# 2 0.5992 {'wins': 12, 'seen': 20}
# BLACK TO MOVE
# 6 _ _ _ x _ _ _
# 5 _ _ _ o x _ _
# 4 _ _ _ x x x o
# 3 _ o _ o o x x
# 2 _ o o x o o o
# 1 _ x o o x x x
#   A B C D E F G
#
# PLAYER WON \+

# %%
ai.Run(3, 0, True)

# %%
table = ai.table

# %%
# b.print_board(list((556206917161, 50538708)), 0)

# %%
seen_tot = 0
wins_tot = 0
for v in table.values():
    seen_tot += v['seen'] - 20
    wins_tot += v['wins'] - 10

#     print(v,k)

print(seen_tot, wins_tot, float(wins_tot) / seen_tot)
avg_seen = seen_tot / len(table)

print(avg_seen)

# %%
ai.Run(1,0,True)

# %%
x = []
for u in range(1000):
    x.append( np.random.randint(0,6))

# %%
max(x)

# %%
min(x)

# %%
\
